# %% [markdown]
# # Cleveland Heart Disease — EDA
#
# Run `python -m heart_mlops.eda` from the project root for saved figures in `artifacts/eda/`, or execute the cells below interactively.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

from heart_mlops.data import load_cleveland_df, add_binary_target

df = add_binary_target(load_cleveland_df(ROOT / "data/raw/processed.cleveland.data"))
df.describe()
